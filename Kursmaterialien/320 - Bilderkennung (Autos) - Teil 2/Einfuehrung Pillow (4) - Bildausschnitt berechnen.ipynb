# %%
from PIL import Image

img = Image.open("bild1.jpg")
img = img.resize((round(img.size[0] / 10), round(img.size[1] / 10)))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=230x173 at 0x7F88D3A057F0>

# %%
#2 Punkte die den Ausschnitt definieren müssen angegeben werden
img.crop((50, 50, 150, 150))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F88D3B92940>

# %%
import numpy as np

i = np.asarray(img.crop((50, 50, 150, 150)))

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.imshow(i)
plt.show()

# %%
i.astype(np.float32) / 255.
# Out:
# array([[[0.39607844, 0.34117648, 0.24313726],
#         [0.30588236, 0.2627451 , 0.18431373],
#         [0.28235295, 0.2509804 , 0.16470589],
#         ...,
#         [0.22745098, 0.18039216, 0.12156863],
#         [0.22352941, 0.1764706 , 0.12156863],
#         [0.23137255, 0.1882353 , 0.1254902 ]],
#
#        [[0.25490198, 0.22745098, 0.18431373],
#         [0.29803923, 0.2627451 , 0.21176471],
#         [0.32156864, 0.28235295, 0.23137255],
#         ...,
#         [0.19607843, 0.14509805, 0.10196079],
#         [0.19215687, 0.14117648, 0.10588235],
#         [0.18431373, 0.12941177, 0.09411765]],
#
#        [[0.21960784, 0.20392157, 0.16862746],
#         [0.24313726, 0.22352941, 0.18431373],
#         [0.27450982, 0.24313726, 0.20784314],
#         ...,
#         [0.17254902, 0.10588235, 0.08235294],
#         [0.16078432, 0.09803922, 0.07450981],
#         [0.16470589, 0.09803922, 0.08235294]],
#
#        ...,
#
#        [[0.8117647 , 0.6156863 , 0.36078432],
# ...
